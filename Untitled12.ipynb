# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
# Create sample dataset
X = np.random.rand(300, 10)  # 300 samples, 10 features
y = np.random.randint(0, 3, 300)  # 3 gesture classes

data = pd.DataFrame(X)
data["label"] = y

data.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.018641  0.574733  0.119310  0.445646  0.217019  0.076937  0.824921
# 1  0.645090  0.594735  0.480890  0.485917  0.009898  0.058540  0.566500
# 2  0.193239  0.619979  0.816848  0.099609  0.781699  0.032255  0.651951
# 3  0.613724  0.236363  0.117738  0.979959  0.073989  0.136400  0.194421
# 4  0.026695  0.516723  0.084054  0.003129  0.553423  0.933136  0.562974
#
#           7         8         9  label
# 0  0.237860  0.557246  0.365533      2
# 1  0.569098  0.565454  0.850405      1
# 2  0.131703  0.669867  0.778077      0
# 3  0.914466  0.236456  0.280497      1
# 4  0.117703  0.305257  0.189630      2

# %%
X_train, X_test, y_train, y_test = train_test_split(
    data.drop("label", axis=1),
    data["label"],
    test_size=0.2,
    random_state=42
)

print("Data split completed")
# Out:
# Data split completed

# %%
model = SVC(kernel="linear")
model.fit(X_train, y_train)

print("Model trained successfully")
# Out:
# Model trained successfully

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print("Model Accuracy:", accuracy)
# Out:
# Model Accuracy: 0.2833333333333333

# %%
plt.bar(["Accuracy"], [accuracy])
plt.title("Hand Gesture Recognition Accuracy")
plt.show()
